# %%
import numpy as np
import scipy as sp
from scipy import optimize
import matplotlib.pyplot as plt
import seaborn as sb

# %%
t = np.linspace(0,10,1000)
funcion_de_test = lambda x: np.sin(x)
plt.plot(t, funcion_de_test(t))
plt.grid(True)
plt.xlabel("nombre del eje x")
plt.ylabel("nombre del eje y")
plt.title("nombre del titulo")
# Out:
# Text(0.5, 1.0, 'nombre del titulo')
